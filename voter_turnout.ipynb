# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df_turnout = pd.read_csv("../voter_turnout.csv")
df_turnout["turnout_vap"] = df_turnout["turnout_vap"].apply(lambda x: float(x[:-1]))
df_turnout["turnout_vep"] = df_turnout["turnout_vep"].apply(lambda x: float(x[:-1]))

df_turnout
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\morit\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\morit\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\morit\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'df_turnout_vap'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.plot(df_turnout["year"], df_turnout["turnout_vap"])
